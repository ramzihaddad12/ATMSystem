# %% [markdown]
# <a href="https://colab.research.google.com/github/ramzihaddad12/ATMSystem/blob/main/term_statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Working with Terms and Documents
#
# This first homework assignment starts off with term statistics computations and graphing. In the final section (for CS6200 students), you collect new documents to experiment with.
#
# Read through this Jupyter notebook and fill in the parts marked with `TODO`.

# %% [markdown]
# ## Sample Data
#
# Start by looking at some sample data. We donwload the counts of terms in documents for the first one million tokens of a newswire collection.

# %%
# !wget -O ap201001.json.gz https://github.com/dasmiq/cs6200-hw1/blob/main/ap201001.json.gz?raw=true
# !gunzip ap201001.json.gz
# Out:
# --2022-09-22 02:05:38--  https://github.com/dasmiq/cs6200-hw1/blob/main/ap201001.json.gz?raw=true
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/dasmiq/cs6200-hw1/raw/main/ap201001.json.gz [following]
# --2022-09-22 02:05:38--  https://github.com/dasmiq/cs6200-hw1/raw/main/ap201001.json.gz
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dasmiq/cs6200-hw1/main/ap201001.json.gz [following]
# --2022-09-22 02:05:39--  https://raw.githubusercontent.com/dasmiq/cs6200-hw1/main/ap201001.json.gz
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2854711 (2.7M) [application/octet-stream]
# Saving to: ‘ap201001.json.gz’
#
# ap201001.json.gz    100%[===================>]   2.72M  --.-KB/s    in 0.07s
#
# 2022-09-22 02:05:39 (41.9 MB/s) - ‘ap201001.json.gz’ saved [2854711/2854711]

# %% [markdown]
# We convert this file with one JSON record on each line to a list of dictionaries.

# %%
import json
rawfile = open('ap201001.json')
terms = [json.loads(line) for line in rawfile]

# %% [markdown]
# Here are the first ten records, showing the count of each term for each document and field. In this dataset, field only takes the values `body` or `title`.

# %%
terms[1:10]
# Out:
# [{'id': 'APW_ENG_20100101.0001', 'field': 'body', 'term': 'about', 'count': 1},
#  {'id': 'APW_ENG_20100101.0001', 'field': 'body', 'term': 'abuse', 'count': 1},
#  {'id': 'APW_ENG_20100101.0001',
#   'field': 'body',
#   'term': 'academy',
#   'count': 1},
#  {'id': 'APW_ENG_20100101.0001',
#   'field': 'body',
#   'term': 'accused',
#   'count': 2},
#  {'id': 'APW_ENG_20100101.0001',
#   'field': 'body',
#   'term': 'actress',
#   'count': 1},
#  {'id': 'APW_ENG_20100101.0001', 'field': 'body', 'term': 'ad', 'count': 1},
#  {'id': 'APW_ENG_20100101.0001', 'field': 'body', 'term': 'after', 'count': 1},
#  {'id': 'APW_ENG_20100101.0001',
#   'field': 'body',
#   'term': 'agenda',
#   'count': 1},
#  {'id': 'APW_ENG_20100101.0001',
#   'field': 'body',
#   'term': 'agreed',
#   'count': 1}]

# %% [markdown]
# Each record has four fields:
# * `id`, with the identifier for the document;
# * `field`, with the region of the document containing a given term;
# * `term`, with the lower-cased term; and
# * `count`, with the number of times each term occurred in that field and document.

# %% [markdown]
# ## Computing Term Statistics

# %% [markdown]
# If we look at the most frequent terms for a given document, we mostly see common function words, such as `the`, `and`, and `of`. Start exploring the dataset by computing some of these basic term statistics. You can make your life easier using data frame libraries such as `pandas`, core python libraries such as `collections`, or just simple list comprehensions.
#
# Feel free to define helper functions in your code before computing the statistics we're looking for.

# %%
import pandas as pd
df = pd.DataFrame(terms, columns = ['id', 'field', 'term', 'count'])

# %%
# TODO: Print the 6 terms from document APW_ENG_20100101.0001 with the highest count.
final_df = df.sort_values(by=['count'], ascending=False)
print(final_df.loc[final_df['id'] == 'APW_ENG_20100101.0001'].head(6))
# Out:
#                         id field    term  count
# 0    APW_ENG_20100101.0001  body       a     16
# 192  APW_ENG_20100101.0001  body     the     11
# 198  APW_ENG_20100101.0001  body      to     10
# 133  APW_ENG_20100101.0001  body      of     10
# 34   APW_ENG_20100101.0001  body  brooks     10
# 15   APW_ENG_20100101.0001  body     and     10

# %%
# TODO: Print the 10 terms from all fields of document APW_ENG_20100102.0077 with the highest count.
final_df = df.sort_values(by=['count'], ascending=False)
print(final_df.loc[final_df['id'] == 'APW_ENG_20100102.0077'].head(10))
# Out:
#                          id field       term  count
# 9604  APW_ENG_20100102.0077  body        the     50
# 9615  APW_ENG_20100102.0077  body         to     21
# 9441  APW_ENG_20100102.0077  body         in     21
# 9301  APW_ENG_20100102.0077  body        and     19
# 9502  APW_ENG_20100102.0077  body         of     14
# 9287  APW_ENG_20100102.0077  body          a     13
# 9642  APW_ENG_20100102.0077  body        was      8
# 9508  APW_ENG_20100102.0077  body         on      8
# 9558  APW_ENG_20100102.0077  body       said      8
# 9480  APW_ENG_20100102.0077  body  militants      8

# %%
# TODO: Print the 10 terms with the highest total count in the corpus.
res = df.groupby(['term'])['count'].sum().reset_index(name ='Total Count')
final_df = res.sort_values(by=['Total Count'], ascending=False)
print(final_df.head(10))
# Out:
#        term  Total Count
# 24646   the        62216
# 24900    to        26931
# 11865    in        25659
# 0         a        23383
# 16991    of        22326
# 944     and        22125
# 21244  said        10888
# 9269    for         9716
# 17109    on         9382
# 24639  that         8942

# %% [markdown]
# Raw counts may not be the most informative statistic. One common improvement is to use *inverse document frequency*, the inverse of the proportion of documents that contain a given term.

# %%
# TODO: Compute the number of distinct documents in the collection.
N = 0
N = df['id'].nunique()
print(N)

# TODO: Compute the number of distinct documents each term appears in
# and store in a dictionary.
res = df.groupby(['term'])['id'].nunique().reset_index(name ='Number of distinct documents')
print(res)
dictionary = res.to_dict()
print(dictionary)
# df = dict()
# Out:
# 2778
#             term  Number of distinct documents
# 0              a                          2571
# 1          aaaar                             1
# 2         aafter                             1
# 3          aamir                             2
# 4      aardvarks                             1
# ...          ...                           ...
# 27551     zurich                            13
# 27552   zuzulova                             2
# 27553     zverev                            12
# 27554    zvornik                             1
# 27555     zwolle                             2
#
# [27556 rows x 2 columns]
# {'term': {0: 'a', 1: 'aaaar', 2: 'aafter', 3: 'aamir', 4: 'aardvarks', 5: 'aare', 6: 'aarhus', 7: 'aaron', 8: 'ab', 9: 'ababa', 10: 'abalone', 11: 'abandon', 12: 'abandoned', 13: 'abandoning', 14: 'abb', 15: 'abbas', 16: 'abbleby', 17: 'abbot', 18: 'abbott', 19: 'abc', 20: "abc's", 21: 'abdel', 22: 'abdellah', 23: 'abdi', 24: 'abdirahman', 25: 'abdolhossein', 26: 'abdomen', 27: 'abdominal', 28: 'abdou', 29: 'abdoulay', 30: 'abdoulaye', 31: 'abducted', 32: 'abducting', 33: 'abductions', 34: 'abdul', 35: 'abdulahi', 36: 'abdulatif', 37: 'abdulla', 38: 'abdullah', 39: 'abdullahi', 40: 'abdulle', 41: 'abdulmutallab', 42: "abdulmutallab's", 43: 'abdulmuttalab', 44: 'abdulzai', 45: 'abdur', 46: 'abe', 47: 'abel', 48: 'abercrombie', 49: 'aberdeen', 50: "aberdeen's", 51: 'abeyance', 52: 'abhisit', 53: 'abide', 54: 'abiding', 55: 'abigail', 56: 'abilities', 57: 'ability', 58: 'ablaze', 59: 'able', 60: 'abn', 61: 'abnormality', 62: 'aboard', 63: 'abolish', 64: 'abolished', 65: 'abolition', 66: 'abort', 67: 'aborted', 68: 'abortion', 69: 'abortions', 70: 'abou', 71: 'aboul', 72: 'aboulafia', 73: 'abounds', 74: 'about', 75: 'above', 76: 'abraham', 77: 'abrahamson', 78: 'abramovich', 79: 'abreu', 80: 'abroad', 81: 'abrogate', 82: 'abrupt', 83: 'abruptly', 84: 'abruscato', 85: 'abscesses', 86: 'absence', 87: 'absences', 88: 'absent', 89: 'absentia', 90: 'absolute', 91: 'absolutely', 92: 'absorb', 93: 'absorbed', 94: 'absorbing', 95: 'absorbs', 96: 'abstract', 97: 'absurd', 98: 'abu', 99: 'abubakar', 100: 'abudema', 101: "abudema's", 102: 'abudllah', 103: 'abuhatzeira', 104: "abuhatzeira's", 105: 'abuja', 106: 'abundance', 107: 'abuse', 108: 'abused', 109: 'abuser', 110: 'abuses', 111: 'abusing', 112: 'abusive', 113: 'abuts', 114: 'abuzz', 115: 'abyan', 116: 'abysmal', 117: 'ac', 118: 'academic', 119: 'academics', 120: 'academy', 121: "academy's", 122: 'accelerate', 123: 'accelerated', 124: 'accelerating', 125: 'accelerative', 126: 'accelerator', 127: 'accelerometers', 128: 'accent', 129: 'accents', 130: 'accenture', 131: 'accept', 132: 'acceptable', 133: 'acceptance', 134: 'acceptances', 135: 'accepted', 136: 'accepting', 137: 'accepts', 138: 'access', 139: 'accessibility', 140: 'accessible', 141: 'accessing', 142: 'accession', 143: 'accessories', 144: 'accident', 145: 'accidental', 146: 'accidentally', 147: 'accidents', 148: 'acclaimed', 149: 'acclimated', 150: 'acclimatized', 151: 'accommodate', 152: 'accommodations', 153: 'accomodate', 154: 'accompanied', 155: 'accompanies', 156: 'accompany', 157: 'accompanying', 158: 'accomplices', 159: 'accomplish', 160: 'accomplished', 161: 'accomplishment', 162: 'accomplishments', 163: 'accord', 164: 'accordance', 165: 'accorded', 166: 'according', 167: 'accordingly', 168: 'accords', 169: 'accosted', 170: 'account', 171: 'accountability', 172: 'accountable', 173: 'accountant', 174: 'accountants', 175: 'accounted', 176: 'accounting', 177: 'accounts', 178: 'accra', 179: "accra's", 180: 'accrington', 181: 'accumulated', 182: 'accumulating', 183: 'accumulations', 184: 'accumulator', 185: 'accuracy', 186: 'accurate', 187: 'accurately', 188: 'accusation', 189: 'accusations', 190: 'accuse', 191: 'accused', 192: 'accuses', 193: 'accusing', 194: 'accustomed', 195: 'accuweather', 196: 'ace', 197: 'acer', 198: 'aces', 199: 'acetone', 200: 'aches', 201: 'achieve', 202: 'achieved', 203: 'achievement', 204: 'achievements', 205: 'achieves', 206: 'achieving', 207: 'achilles', 208: 'acidic', 209: 'acidity', 210: 'acids', 211: 'acitvist', 212: 'acknowledge', 213: 'acknowledged', 214: 'acknowledges', 215: 'acknowledging', 216: 'acknowledgment', 217: 'acolytes', 218: 'acquaint', 219: 'acquire', 220: 'acquired', 221: 'acquiring', 222: 'acquisition', 223: 'acquisitions', 224: 'acquits', 225: 'acquittal', 226: 'acquitted', 227: 'acre', 228: 'acreage', 229: 'acres', 230: 'acrobatically', 231: 'acronym', 232: 'acronyms', 233: 'across', 234: 'acrylic', 235: 'act', 236: 'acted', 237: 'acting', 238: 'action', 239: 'actions', 24 ...

# %%
# TODO: Print the relative document frequency of 'the',
# i.e., the number of documents that contain 'the' divided by N.
n = res.loc[res['term'] == 'the']['Number of distinct documents'].values[0]
print(n/N)
# Out:
# 0.9704823614110871

# %% [markdown]
# Empricially, we usually see better retrieval results if we rescale term frequency (within documents) and inverse document frequency (across documents) with the log function. Let the `tfidf` of term _t_ in document _d_ be:
# ```
# tfidf(t, d) = log(count(t, d) + 1) * log(N / df(t))
# ```
#
# Later in the course, we will show a probabilistic derivation of this quantity based on smoothing language models.

# %%
# TODO: Compute the tf-idf value for each term in each document.
# Take the raw term data and add a tfidf field to each record.

import math

print(df)
print(res)
tfidf = []
for index, row in df.iterrows():
    tfidf.append(math.log(row['count'] + 1) * math.log(N / res.loc[res['term'] == row['term']]['Number of distinct documents'].values[0]))
tfidf_terms = None
# Out:
#                            id  field     term  count
# 0       APW_ENG_20100101.0001   body        a     16
# 1       APW_ENG_20100101.0001   body    about      1
# 2       APW_ENG_20100101.0001   body    abuse      1
# 3       APW_ENG_20100101.0001   body  academy      1
# 4       APW_ENG_20100101.0001   body  accused      2
# ...                       ...    ...      ...    ...
# 538296  APW_ENG_20100107.1067  title  labored      1
# 538297  APW_ENG_20100107.1067  title      led      1
# 538298  APW_ENG_20100107.1067  title        s      1
# 538299  APW_ENG_20100107.1067  title       to      1
# 538300  APW_ENG_20100107.1067  title       us      1
#
# [538301 rows x 4 columns]
#             term  Number of distinct documents
# 0              a                          2571
# 1          aaaar                             1
# 2         aafter                             1
# 3          aamir                             2
# 4      aardvarks                             1
# ...          ...                           ...
# 27551     zurich                            13
# 27552   zuzulova                             2
# 27553     zverev                            12
# 27554    zvornik                             1
# 27555     zwolle                             2
#
# [27556 rows x 2 columns]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-6551467ec4be> in <module>
#       7 print(res)
#       8 tfidf = []
# ----> 9 for index, row in df.iterrows():
#      10     tfidf.append(math.log(row['count'] + 1) * math.log(N / res.loc[res['term'] == row['term']]['Number of distinct documents'].values[0]))
#      11 tfidf_terms = None
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in iterrows(self)
#    1261         klass = self._constructor_sliced
#    1262         for k, v in zip(self.index, self.values):
# -> 1263             s = klass(v, index=columns, name=k)
#    1264             yield k, s
#    1265
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     353             name = ibase.maybe_extract_name(name, data, type(self))
#     354
# --> 355             if is_empty_data(data) and dtype is None:
#     356                 # gh-17261
#     357                 warnings.warn(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/construction.py in is_empty_data(data)
#     793     """
#     794     is_none = data is None
# --> 795     is_list_like_without_dtype = is_list_like(data) and not hasattr(data, "dtype")
#     796     is_simple_empty = is_list_like_without_dtype and not data
#     797     return is_none or is_simple_empty
#
# KeyboardInterrupt:

# %%
# TODO: Print the 20 term-document pairs with the highest tf-idf values.

# %% [markdown]
# ## Plotting Term Distributions
#
# Besides frequencies and tf-idf values within documents, it is often helpful to look at the distrubitions of word frequencies in the whole collection. In class, we talk about the Zipf distribution of word rank versus frequency and Heaps' Law relating the number of distinct words to the number of tokens.
#
# We might examine these distributions to see, for instance, if an unexpectedly large number of very rare terms occurs, which might indicate noise added to our data.

# %%
# TODO: Compute a list of the distinct words in this collection and sort it in descending order of frequency.
# Thus frequency[0] should contain the word "the" and the count 62216.

frequency = final_df['term'].tolist()
print(frequency)
# Out:
# ['the', 'to', 'in', 'a', 'of', 'and', 'said', 'for', 'on', 'that', 'was', 'is', 'with', 'at', 'he', 'it', 'from', 'as', 'by', 'has', 'an', 'have', 'his', 'be', 'but', 's', 'u', 'were', 'not', 'are', 'will', 'its', 'who', 'had', 'after', 'year', 'they', 'this', 'new', 'been', 'more', 'two', 'security', 'or', 'which', 'about', 'percent', 'up', 'their', 'al', 'would', 'also', 'last', 'first', 'than', 'i', 'one', 'other', 'people', 'out', 'government', 'officials', 'over', 'when', 'we', 'police', 'no', 'into', 'there', 'against', 'because', 'since', 'says', 'time', 'three', 'could', 'wednesday', 'million', 'monday', 'years', 'some', 'before', 'tuesday', 'yemen', 'all', 'she', 'united', 'president', 'her', 'report', 'international', 'day', 'while', 'official', 'second', 'down', 'only', 'him', 'if', 'qaida', 'states', 'told', 'world', 'old', 'off', 'attack', 'them', 'through', 'group', 'state', 'intelligence', 'month', 'killed', 'where', 'say', 'including', 'man', 'any', 'so', 'press', 'just', 'now', 'many', 'can', 'billion', 'south', 'still', 'during', 'back', 'high', 'minister', 'former', 'what', 'points', 'most', 'made', 'under', 'obama', 'four', 'thursday', 'country', 'company', 'city', "it's", 'week', 'between', 'being', 'authorities', 'third', 'home', 'american', 'airport', 'associated', 'statement', 'court', 'top', 'did', 'set', 'sunday', 'national', 'later', 'those', 'us', 'you', 'five', 'rose', 'like', 'cup', 'then', 'several', 'oil', 'such', 'spokesman', 'house', 'season', 'match', 'both', 'game', 'make', 'may', 'afghanistan', 'saturday', 'get', 'expected', 'even', 'take', 'sales', 'british', 'open', 'britain', 'another', 'do', 'won', 'war', 'market', 'december', 'pakistan', 'passengers', 'well', 'left', 'win', 'team', 'washington', 'def', 'six', 'reported', 'cia', 'our', 'public', 'countries', 'according', 'least', 'held', 'go', 'economic', 'information', 'federal', 'based', 'months', 'how', 'called', 'ministry', 'capital', 'should', 'took', 'foreign', 'earlier', 'christmas', 'late', 'lead', 'news', 'militants', 'york', 'contributed', 'service', 'forces', 'failed', 'work', 'north', 'november', 'league', 'part', 'attacks', 'help', 'past', 'family', 'border', 'way', 'area', 'early', 'england', 'saying', 'office', 'chief', 'scored', 'already', 'next', 'military', 'minutes', 'run', 'long', 'led', 'around', 'without', 'end', 'embassy', 'seven', 'added', 'much', 'fell', 'vs', 'however', 'european', 'major', 'bank', 'whether', 'near', 'prices', 'china', 'economy', 'dec', 'yemeni', 'support', 'money', 'place', 'play', 'decision', 'days', 'agency', 'my', 'administration', 'until', 'white', 'among', 'recent', 'came', "didn't", 'used', 'west', 'jan', 'france', 'final', 'deal', 'use', 'africa', 'program', 'flight', 'condition', 'put', 'aid', 'explosives', 'stock', 'power', 'half', 'dubai', 'local', 'israel', 'case', 'body', 'number', 'show', 'germany', 'iran', 'good', 'weeks', 'eight', 'games', 'officer', 'very', 'going', 'beat', 'leader', 'muslim', 'close', 'abdulmutallab', 'right', 'business', 'site', 'announced', 'own', 'results', 'trying', 'think', 'index', 'died', 'players', 'record', 'meeting', 'region', 'hit', 'suspected', 'lost', 'offer', 'ago', 'too', 'department', 'members', 'list', 'full', 'each', 'death', 'health', 'nearly', 'party', 'bomb', 'plans', 'trading', 'jobs', 'head', 'detroit', 'far', 'russia', 'gaza', 'hours', 'others', 'anti', 'give', 'system', 'following', 'began', 'found', 'point', 'reports', 'markets', 'few', 'test', 'defense', 'key', 'released', 'though', 'men', 'start', 'terror', 'ahead', 'plane', "country's", 'higher', 'gas', 'jordanian', 'london', 'ap', 'friday', 'law', 'round', 'big', 'workers', 'outside', 'less', 'price', 'see', 'threat', 'explosive', 'analysts', 'need', 'these', 'central', 'terrorist', 'control', 'tv', "don't", 'b', 'fourth', 'global', 'french', 'behind', 'charges', 'return', 'anonymity', 'australia', 'sea', 'investors', 'arrested', 'bill', 'further', 'keep', 'bound', 'corp', 'gave', ...

# %%
# TODO: Plot a graph of the log of the rank (starting at 1) on the x-axis,
# against the log of the frequency on the y-axis. You may use the matplotlib
# or other library.

# %%
# TODO: Compute the number of tokens in the corpus.
# Remember to count each occurrence of each word. For instance, the 62,216
# instances of "the" will all count here.
ntokens = 0

# %%
# TODO: Compute the proportion of tokens made up by the top 10 most
# frequent words.

# %%
# TODO: Compute the proportion of tokens made up by the words that occur
# exactly once in this collection.

# %% [markdown]
# ## Acquiring New Documents (for CS6200)
#
# For this assignment so far, you've worked with data that's already been extracted, tokenized, and counted. In this final section, you'll explore acquiring new data.
#
# One common way of acquiring data is through application programming interfaces (APIs) to various databases. The Library of Congress's [_Chronicling America_](https://chroniclingamerica.loc.gov/) site aggregates digitized US newspapers from the past two hundred years, such as the [_Seattle Star_](https://chroniclingamerica.loc.gov/lccn/sn87093407/1922-09-19/ed-1/seq-1/) from 100 years ago.
#
# You can use [the API](https://chroniclingamerica.loc.gov/about/api/) to retrieve JSON data listing all issues of the _Seattle Star_: https://chroniclingamerica.loc.gov/lccn/sn87093407.json
#
# Note the list in the `issues` field. For example, here is the record for the September 19, 1922, issue: https://chroniclingamerica.loc.gov/lccn/sn87093407/1922-09-19/ed-1.json
#
# In that issue record, you'll see records for each page, e.g.: https://chroniclingamerica.loc.gov/lccn/sn87093407/1922-09-19/ed-1/seq-1.json
#
# And inside that page record, you'll see links to data about that page in various data formats, such as JPEG, PDF, and plain text, which is what we want here: https://chroniclingamerica.loc.gov/lccn/sn87093407/1922-09-19/ed-1/seq-1/ocr.txt
#
# This plain text was transcribed from the old page images using optical character recognition (OCR) models, and so contains errors.
#
# Your task is to acquire and analyze the issues of the _Seattle Star_ from the month of September, 1922, i.e., the issues with a date field that starts with `1922-09`. This should be about the same amount of data as the million words from the Associated Press you analyzed in the last section.

# %% [markdown]
# **TODO**: Write code that calls the _Chronicling America_ API to download and extract the text from the _Seattle Star_ from September 1922. You can use the `json` library from above and any other libraries you wish to fetch data from URLs. As you would when working with any production API, you may need to limit your rate of requests.

# %%
# TODO: Data acquisition code here.

# %% [markdown]
# **TODO**: Write code to tokenize the text and count the resulting terms in each document. Since this data comes from automatically transcribing printed pages, some words may be hyphenated across line breaks. There is more than one right way to tokenize this data, so add comments to your code documenting your choices.

# %%
# TODO: Tokenization code here.

# %% [markdown]
# **TODO**: Plot a graph of the log rank against log frequency for your collection, as you did for the sample collection above.

# %%
# TODO: Plotting code here.

# %% [markdown]
# **TODO**: What do you observe about the differences between the distributions of the Associated Press and Seattle Star collections? In this text box, give some possible reasons for these differences.
